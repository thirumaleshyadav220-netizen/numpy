# %% [markdown]
# <a href="https://colab.research.google.com/github/thirumaleshyadav220-netizen/numpy/blob/main/t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create numpy arrays with single dim
import numpy as np
a=44
value=np.array(a)
print(value)
print(type(value))
# Out:
# 44
# <class 'numpy.ndarray'>
