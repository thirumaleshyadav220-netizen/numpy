# %% [markdown]
# <a href="https://colab.research.google.com/github/thirumaleshyadav220-netizen/numpy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def get_matrix()
    input(f"Enter number of rows for {name}: "))
    cols = int(input(f"Enter number of columns for {name}: "))
    print(f"Enter elements for {name} row-wise:")
    elements = []
    for i in range(rows):
        row = list(map(float, input(f"Row {i+1}: ").split()))
        if len(row) != cols:
            raise ValueError("Incorrect number of elements in row.")
        elements.append(row)
    return np.array(elements)

def main():
    print("Matrix Operations Program\n")

    # Input matrices
    A = get_matrix("Matrix A")
    B = get_matrix("Matrix B")

    print("\nMatrix A:\n", A)
    print("Matrix B:\n", B)

    # Addition
    if A.shape == B.shape:
        print("\nAddition (A + B):\n", A + B)
    else:
        print("\nAddition not possible: Shape mismatch.")
